# %% [markdown]
# # 01 — Python basics
#
# Run one cell at a time. Each code cell is one idea: a short example, then the result in a comment.

# %% [markdown]
# **Table of contents**
#
# - [Printing, variables, comments](#printing-variables-comments)
# - [Strings](#strings)
# - [Numbers and operators](#numbers-and-operators)
# - [Type conversion](#type-conversion)
# - [Decisions](#decisions)

# %% [markdown]
# ## Printing, variables, comments

# %%
# Printing a string
print("Hello World!")  # Hello World!
# Out:
# Hello World!

# %%
# Variables
student_count = 10000          # int
rating = 4.99                  # float
is_published = True            # bool
course_name = "Python for Beginners"  # str

print("student_count -->", student_count)  # 10000
print("rating        -->", rating)         # 4.99
print("is_published  -->", is_published)   # True
print("course_name   -->", course_name)    # Python for Beginners
print("type(rating)  -->", type(rating))   # <class 'float'>
# Out:
# student_count --> 10000
# rating        --> 4.99
# is_published  --> True
# course_name   --> Python for Beginners
# type(rating)  --> <class 'float'>

# %%
# Comments
# This line is a note to you. Python ignores it.
print("Comments do not run")  # Comments do not run
# Out:
# Comments do not run

# %% [markdown]
# ## Strings

# %%
# String methods
course_name = "Python for Beginners"
print("len(course_name)        -->", len(course_name))         # 20
print("course_name.upper()     -->", course_name.upper())      # PYTHON FOR BEGINNERS
print("course_name.lower()     -->", course_name.lower())      # python for beginners
print("course_name.title()     -->", course_name.title())      # Python For Beginners
print("course_name.replace()   -->", course_name.replace("Python", "Java"))  # Java for Beginners
print("course_name.find()      -->", course_name.find("Python"))  # 0
print("course_name.count()     -->", course_name.count("o"))   # 2
print("course_name             -->", course_name)              # original value remains unchanged
# Out:
# len(course_name)        --> 20
# course_name.upper()     --> PYTHON FOR BEGINNERS
# course_name.lower()     --> python for beginners
# course_name.title()     --> Python For Beginners
# course_name.replace()   --> Java for Beginners
# course_name.find()      --> 0
# course_name.count()     --> 2
# course_name             --> Python for Beginners

# %%
# Slicing
course_name = "Python for Beginners"
print("course_name[0]      -->", course_name[0])       # P
print("course_name[0:6]    -->", course_name[0:6])     # Python
print("course_name[:6]     -->", course_name[:6])      # Python
print("course_name[11:]    -->", course_name[11:])     # Beginners
print("course_name[-4:]    -->", course_name[-4:])     # ners
# Out:
# course_name[0]      --> P
# course_name[0:6]    --> Python
# course_name[:6]     --> Python
# course_name[11:]    --> Beginners
# course_name[-4:]    --> ners

# %%
# Escape sequences
print('double quotes -->', "Python \"for\" Beginners")  # Python "for" Beginners
print("single quotes -->", "Python 'for' Beginners")    # Python 'for' Beginners
print("backslash     -->", "Python \\for\\ Beginners")  # Python \for\ Beginners
print("newline       -->", "Python\nfor\nBeginners")
# Out:
# double quotes --> Python "for" Beginners
# single quotes --> Python 'for' Beginners
# backslash     --> Python \for\ Beginners
# newline       --> Python
# for
# Beginners

# %%
# Formatted strings (f-strings)
first = "John"
last = "Smith"
print(f"{first} [{last}] is a coder")           # John [Smith] is a coder
print(f"{len(first)} letters in {first}")       # 4 letters in John
# Out:
# John [Smith] is a coder
# 4 letters in John

# %%
# Padding
first = "John"
print(first.ljust(10, "*"))   # John******
print(first.rjust(10, "*"))   # ******John
print(first.center(10, "*"))  # ***John***
# Out:
# John******
# ******John
# ***John***

# %% [markdown]
# ## Numbers and operators

# %%
# Arithmetic
print("10 + 3  -->", 10 + 3)   # 13
print("10 - 3  -->", 10 - 3)   # 7
print("10 * 3  -->", 10 * 3)   # 30
print("10 / 3  -->", 10 / 3)   # 3.333...  (always float)
print("10 // 3 -->", 10 // 3)  # 3         (integer division)
print("10 % 3  -->", 10 % 3)   # 1         (remainder)
print("10 ** 3 -->", 10 ** 3)  # 1000      (power)
# Out:
# 10 + 3  --> 13
# 10 - 3  --> 7
# 10 * 3  --> 30
# 10 / 3  --> 3.3333333333333335
# 10 // 3 --> 3
# 10 % 3  --> 1
# 10 ** 3 --> 1000

# %%
# Augmented assignment
x = 10
x += 3
print("x += 3 -->", x)  # 13
x -= 3
print("x -= 3 -->", x)  # 10
x *= 3
print("x *= 3 -->", x)  # 30
# Out:
# x += 3 --> 13
# x -= 3 --> 10
# x *= 3 --> 30

# %%
# Comparison operators
x, y = 10, 20
print("x == y -->", x == y)  # False
print("x != y -->", x != y)  # True
print("x > y  -->", x > y)   # False
print("x < y  -->", x < y)   # True
print("x >= y -->", x >= y)  # False
print("x <= y -->", x <= y)  # True
# Out:
# x == y --> False
# x != y --> True
# x > y  --> False
# x < y  --> True
# x >= y --> False
# x <= y --> True

# %%
# Logical operators
x, y = True, False
print("x and y -->", x and y)  # False
print("x or y  -->", x or y)   # True
print("not x   -->", not x)    # False
# Out:
# x and y --> False
# x or y  --> True
# not x   --> False

# %%
# Useful number helpers
import math

print("round(2.6)     -->", round(2.6))       # 3
print("abs(-2.6)      -->", abs(-2.6))        # 2.6
print("pow(2, 3)      -->", pow(2, 3))        # 8
print("math.ceil(2.6) -->", math.ceil(2.6))   # 3
print("math.floor(2.6)-->", math.floor(2.6))  # 2
print("math.sqrt(16)  -->", math.sqrt(16))    # 4.0
# Out:
# round(2.6)     --> 3
# abs(-2.6)      --> 2.6
# pow(2, 3)      --> 8
# math.ceil(2.6) --> 3
# math.floor(2.6)--> 2
# math.sqrt(16)  --> 4.0

# %% [markdown]
# ## Type conversion
#
# `input()` always returns a **string**. Convert it before doing math.
#
# Skip the next cell if you do not want the notebook to wait for typing.

# %%
# input() returns a string — convert before doing math
age = input("Enter your age: ")
print("type(age)     -->", type(age))          # <class 'str'>
print("int(age) + 1  -->", int(age) + 1)
print("float(age)    -->", float(age))
print('bool("")      -->', bool(""))           # False
print("bool(0)       -->", bool(0))            # False
print("bool(1)       -->", bool(1))            # True
print("bool(3)       -->", bool(3))            # True
# Out:
# type(age)     --> <class 'str'>
# int(age) + 1  --> 5
# float(age)    --> 4.0
# bool("")      --> False
# bool(0)       --> False
# bool(1)       --> True
# bool(3)       --> True

# %% [markdown]
# ## Decisions

# %%
# if / else
x, y = 10, 20
if x > y:
    print("x is greater than y")
else:
    print("x is less than y")  # this line runs
# Out:
# x is less than y

# %%
# if / elif / else
x, y = 10, 20
if x > y:
    print("x is greater")
elif x < y:
    print("x is less")  # this line runs
else:
    print("x equals y")


x, y = 10, 10
if x > y:
    print("x is greater")
elif x < y:
    print("x is less")  # this line runs
else:
    print("x equals y")
# Out:
# x is less
# x equals y

# %%
# Ternary (one-line if)
x, y = 10, 20
result = "x is greater" if x > y else "x is less"
print(result)  # x is less
# Out:
# x is less

# %%
# Chained comparisons
age = 22
if 18 <= age < 65:
    print("adult, not retirement age")  # this line runs
# Out:
# adult, not retirement age
